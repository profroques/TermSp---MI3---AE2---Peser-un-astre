# %% [markdown]
# <div class="panel panel-primary">
#     <div class="panel-heading"><h2>Préambule :</h2></div>
#       <div class="panel-body">
# Dans cette interface, vous allez découvrir des blocs de code qui composent un programme informatique complet.
#
# Afin de vous permettre de vous initier au codage et de vous faire participer à compléter ce programme informatique, le programme sera fragmenté par blocs.
#
# Ainsi, vous serez sollicité.e.s pour deux types d'action. <br>
# - un travail pour <i>exécuter</i> un bloc de programme informatique ;<br>
# - un travail pour <i>compléter</i> un bloc de programme informatique.<br>
# <br>
# Avant de commencer à découvrir le contenu du programme informatique proposé, je vous invite à prendre connaissance des différents types de consignes et des codes couleurs associés que vous allez rencontrer.
#       </div>
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <b>Informations pour exécuter un bloc de programme informatique : </b> <br>
# <br><i>Avant</i> les blocs de programme qu'il faut simplément "exécuter", vous trouverez :<br>
# la consigne de travail sur un fond bleu avec une écriture en bleu foncé comme pour cette consigne.<br>
#
# Pour Exécuter le code dans un bloc de programme, il faut le sélectionner en cliquant sur la cellule du bloc, puis cliquer sur le bouton Run (ou Exécuter) <b>en haut de la page</b> ou bien en cliquant sur la flèche à côté de In (ou Entrée) si vous êtes sur tablettes ou smartphones.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Informations pour compléter un bloc de programme informatique: </b> <br>
# Certains blocs de codes doivent être complétés <span style='border:1px outset black'>avant</span> d'être exécutés afin de fonctionner convenablement.<br>
# <br><i>Avant</i> les blocs de programme qu'il faut "compléter", vous trouverez:
# <br> -la consigne de travail sur un fond jaune avec une écriture en brun - comme pour cette consigne.
# <br>-Dans le bloc de programme à compléter vous remplacerez la mention "-----A COMPLETER-----" par le code adapté.
# <br>-Dans certains cas, il est possible d'avoir des aides et/ou la solution.
# <br><b>ATTENTION : Une fois le programme complété, il faut alors exécuter le bloc de code correspondant.</b>
# </div>

# %% [markdown]
# <h1> INTERFACE - Tester la 3ème loi de Kepler pour peser la masse d'un astre - Term Spé PhyChim</h1>

# %% [markdown]
# <div class="panel panel-default">
#       <div class="panel-heading"><h2>Tester la 3ème loi de Kepler pour peser la masse d'un astre - Term Spé PhyChim</h2></div>
#        <div class="panel-body">Tout d'abord, un rappel : ce programme a pour but de Tester la 3ème loi de Kepler pour peser la masse d'un astre </div>
# <div class="panel-body">
# Dans cette interface, vous allez découvrir des blocs de code qui composent un programme informatique. Ce programme a pour but :</div>
# <div class="panel-body">
# 1] de demander à l'opératrice ou à l'opérateur de saisir des valeurs caractérisques d'une planète. Par défaut, les caractéristiques de Jupiter sont proposées.
#     </div>
# <div class="panel-body">
# 2] de demander à l'opératrice ou à l'opérateur de modifier un bloc de programme pour créer la variable x = T<sup>2</sup> et y=a<sup>3</sup> ainsi que l'expression de la masse M de l'astre étudié.
#     </div>
#
#
# <div class="panel-body">
# 3] d'exécuter un bloc pour tracer T<sup>2</sup> en fonction de a<sup>3</sup> et d'obtenir la valeur de la masse de l'astre.
#     </div>
#
# <div class="panel-body">
# Afin de vous permettre de vous initier au codage et de vous faire participer pour compléter ce programme informatique, le programme sera donc fragmenté par bloc selon les modalités et consignes d'usages rappelées au début de cette page.
#     <br>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <b>TRAVAIL À FAIRE POUR EXÉCUTER LE BLOC SUIVANT </b> <br>
# <br>
#     Le bloc de programme suivant d'importer la librairie pyplot qui permet de faire des tracés et numpy pour des calculs spécifiques.
#
# <br>
# Par défaut, les caractéristiques de Jupiter sont saisies. Elles peuvent être changer pour étudier un autre astre.
# <br>
#
# <br>
# <br>
# Exécuter le bloc en faisant un "clic gauche" sur ce bloc puis en choisissant "Exécuter" dans la barre d'outils.
# <br>
# <br>
#
# </div>

# %%
import matplotlib.pyplot as plt
from math import *
from scipy.stats import linregress
import numpy as np
import numpy.polynomial.polynomial as nppol

print("")
print("*********************************************")
print("*     Tester la troisieme loi de Kepler     *")
print("*             et peser un astre             *")
print("*********************************Hatier 2020*")
print("")

#########################################
### DONNEES A MODIFIER (Question 1.a) ###
#########################################

### Nom de l'astre attracteur
nomastre="Jupiter"
### Masse tabulee de l'astre attracteur en kg
M=1.898e27

### Liste des noms des satellites (entre "")
satellites=["Io","Europe","Ganymede","Callisto","Himalia","Carpo","Hegemone"]
### Liste des demi-grands axes en km
a=[421800,671100,1070400,1882700,11461000,16989000,23947000]

### Liste des periodes orbitales en j
T=[1.769,3.551,7.155,16.689,251.73,456.1,769.6]

### Donnees a ne pas modifier
### Constante de la gravitation universelle en USI
G=6.67e-11
### Initialisation des grandeurs et des tableaux
x=np.zeros(len(satellites))
y=np.zeros(len(satellites))

# %% [markdown]
# <div class="alert alert-warning">
# <b>TRAVAIL À FAIRE POUR COMPLÉTER LE BLOC SUIVANT </b> <br>
# <br>
# Le bloc suivant permet de créer deux variables x = T<sup>2</sup> et y=a<sup>3</sup> ainsi que la grandeur masse M de l'astre étudié.
# <br>
# <br>
#
# <br>
# <br>
# Remplacer alors les mentions "-----A COMPLETER-----" par une expression adaptée.
#
# <br>
# <br>
#
# <br>
# <b>ATTENTION : Une fois le programme complété, il ne faut pas oublier de l'exécuter.
#     </div>

# %% [markdown]
# <details>
# <summary>Aide</summary>
# <p>Vous devez compléter les lignes n°11 et n°12 ainsi que n°33 en remplaçant la mention "---A COMPLETER----" par le calcul adapté. Ne pas oublier que pour calculer le carré d'une valeur, il faut saisir valeur**2 et pour calculer le cube d'une valeur, il faut saisir valeur**3.</p>
# </details>
#
# <details>
# <summary>Solution</summary>
# <p>On modifie alors les mentions ---A COMPLETER----de la manière suivante : <br></p>
#     <p>x[i]=log(a[i]*1000)</p>
#     <p>y[i]=log(T[i]*86400)</p>
#     <p>Mcalc=4*pi**2/(G*m)</p>
#
# </details>

# %%
###############################
### A MODIFIER (Question 3) ###
###############################
tracelog=False

################################
### A MODIFIER (Question 2a) ###
################################
### Liste des T carres et des a cubes en USI
for i in range(len(a)):
	x[i]=float((-----A COMPLETER-----)
	y[i]=-----A COMPLETER-----

### Ne pas modifier
### Regression lineaire (fonction lineaire)
reg=nppol.polyfit(x,y,[1])

if tracelog==True:
	for i in range(len(a)):
		x[i]=log(a[i]*1000)
		y[i]=log(T[i]*86400)
### Regression lineaire (fonction affine)
	reg=nppol.polyfit(x,y,[0,1])

##m,p,rho,_,_=linregress(x,y)

m=reg[1]
p=reg[0]

################################
### A MODIFIER (Question 2b) ###
################################
Mcalc=-----A COMPLETER-----

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <b>TRAVAIL À FAIRE POUR EXÉCUTER LE BLOC SUIVANT </b> <br>
# <br>
#     Le bloc de programme suivant de tracer T<sup>2</sup> en fonction de a<sup>3</sup>, de calculer le coefficient direction <i>m</i> et de donner la valeur de la masse M de l'astre étudié.
#
# <br>
# Par défaut, les caractéristiques de Jupiter sont saisies. Elles peuvent être changer pour étudier un autre astre.
# <br>
#
# <br>
# <br>
# Exécuter le bloc en faisant un "clic gauche" sur ce bloc puis en choisissant "Exécuter" dans la barre d'outils.
# <br>
# <br>
#
# </div>

# %%
typereg="Trace de T^2 en fonction de a^3"
if tracelog==True:
	Mcalc=4*pi**2/(G*e**(2*p))
	typereg="Trace de ln(T) en fonction de ln(a)"

print("**** Astre etudie:",nomastre,"****")
print("****",typereg,"****")
print("Coefficient directeur de la regression")
print("m=",format(m,"4.3E"),"USI")
if tracelog==True:
	print("Ordonnee a l'origine de la regression")
	print("p=",format(p,"4.3E"),"USI")
print("")
print("Masse tabulee de l'astre attracteur")
print("M=",format(M,"4.3E"),"kg")
print("Masse calculee de l'astre attracteur")
print("M=",format(Mcalc,"4.3E"),"kg")

xmin=0
xmax=1.05*max(x)
if tracelog==True:
	xmin=0.95*min(x)

xmodele=[xmin,xmax]
ymodele=[m*xmin+p,m*xmax+p]

plt.xlabel("a^3 (m^3)")
plt.ylabel("T^2 (s^2)")

if tracelog==True:
	xlabel("ln(a) (USI)")	
	ylabel("ln(T) (USI)")
plt.plot(x,y,"+")
for i in range(len(a)):
	plt.annotate(satellites[i],(x[i],y[i]))
plt.plot(xmodele,ymodele)
plt.grid(True)
plt.show()
